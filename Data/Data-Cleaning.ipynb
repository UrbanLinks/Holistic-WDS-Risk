# %% [markdown]
# Importing the necessary package

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from numpy.linalg import eig
import matplotlib.pyplot as plt
import seaborn as sn
import plotly.express as px
import plotly.graph_objects as go
import os
from factor_analyzer import Rotator
import seaborn as sns
import json
import geojson
from scipy.stats import weibull_min
import matplotlib.pyplot as plt
import plotly.express as px
import geopandas as gpd
import plotly.io as pio

# %% [markdown]
# Reading the data from the .csv file

# %%
df = pd.read_csv('Variable in DAs.csv', encoding='latin-1', low_memory=False)
df
# Out:
#         CENSUS_YEAR              DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 0              2021  2021S051259150307      59150307  Dissemination area
# 1              2021  2021S051259150307      59150307  Dissemination area
# 2              2021  2021S051259150307      59150307  Dissemination area
# 3              2021  2021S051259150307      59150307  Dissemination area
# 4              2021  2021S051259150307      59150307  Dissemination area
# ...             ...                ...           ...                 ...
# 471883         2021  2021S051259154196      59154196  Dissemination area
# 471884         2021  2021S051259154196      59154196  Dissemination area
# 471885         2021  2021S051259154196      59154196  Dissemination area
# 471886         2021  2021S051259154196      59154196  Dissemination area
# 471887         2021  2021S051259154196      59154196  Dissemination area
#
#         GEO_NAME  CHARACTERISTIC_ID  \
# 0       59150307                126
# 1       59150307                127
# 2       59150307                128
# 3       59150307                129
# 4       59150307                130
# ...          ...                ...
# 471883  59154196               2619
# 471884  59154196               2620
# 471885  59154196               2621
# 471886  59154196               2622
# 471887  59154196               2623
#
#                                       CHARACTERISTIC_NAME  \
# 0                                                     NaN
# 1         Number of total income recipients aged 15 ye...
# 2           Average total income in 2020 among recipie...
# 3         Number of after-tax income recipients aged 1...
# 4           Average after-tax income in 2020 among rec...
# ...                                                   ...
# 471883                       Between 6 a.m. and 6:59 a.m.
# 471884                       Between 7 a.m. and 7:59 a.m.
# 471885                       Between 8 a.m. and 8:59 a.m.
# 471886                      Between 9 a.m. and 11:59 a.m.
# 471887                      Between 12 p.m. and 4:59 a.m.
#
#         CHARACTERISTIC_NOTE  C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  \
# 0                      11.0           590.0          315.0            275.0
# 1                       NaN           555.0          295.0            265.0
# 2                       NaN         63400.0        77000.0          48400.0
# 3                       NaN           555.0          295.0            265.0
# 4                       NaN         51600.0        60400.0          41600.0
# ...                     ...             ...            ...              ...
# 471883                  NaN            50.0           20.0             25.0
# 471884                  NaN           110.0           70.0             40.0
# 471885                  NaN            50.0           15.0             30.0
# 471886                  NaN            85.0           40.0             45.0
# 471887                  NaN            80.0           45.0             30.0
#
#         C10_RATE_TOTAL  C11_RATE_MEN+  C12_RATE_WOMEN+ Unnamed: 14
# 0                100.0          100.0            100.0         NaN
# 1                 94.1           93.7             96.4         NaN
# 2              63400.0        77000.0          48400.0         NaN
# 3                 94.1           93.7             96.4         NaN
# 4              51600.0        60400.0          41600.0         NaN
# ...                ...            ...              ...         ...
# 471883            13.5            9.8             14.7         NaN
# 471884            29.7           34.1             23.5         NaN
# 471885            13.5            7.3             17.6         NaN
# 471886            23.0           19.5             26.5         NaN
# 471887            21.6           22.0             17.6         NaN
#
# [471888 rows x 15 columns]

# %% [markdown]
# Selecting only specific characteristics

# %%
selected_variables = ['1539', '1540', '1462', '1463', '1464', '1999', '2001', '1993', 
                      '1416', '1453', '2620', '1827', '1757', '1771', '1705', '1713', 
                      '1684', '1403', '1082', '252', '1467', '151', '1488',
                      '128', '2226', '2224', '2225', '2227', '2248', '1441', '1442', 
                      '1443', '1444', '2607', '1976', '1433', '1451', '2223','1715']
selected_variables = list(map(int, selected_variables))
filtered_df = df[df['CHARACTERISTIC_ID'].isin(selected_variables)]
filtered_df
# Out:
#         CENSUS_YEAR              DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 2              2021  2021S051259150307      59150307  Dissemination area
# 25             2021  2021S051259150307      59150307  Dissemination area
# 55             2021  2021S051259150307      59150307  Dissemination area
# 82             2021  2021S051259150307      59150307  Dissemination area
# 104            2021  2021S051259150307      59150307  Dissemination area
# ...             ...                ...           ...                 ...
# 471794         2021  2021S051259154196      59154196  Dissemination area
# 471795         2021  2021S051259154196      59154196  Dissemination area
# 471816         2021  2021S051259154196      59154196  Dissemination area
# 471873         2021  2021S051259154196      59154196  Dissemination area
# 471884         2021  2021S051259154196      59154196  Dissemination area
#
#         GEO_NAME  CHARACTERISTIC_ID  \
# 2       59150307                128
# 25      59150307                151
# 55      59150307                252
# 82      59150307               1082
# 104     59150307               1403
# ...          ...                ...
# 471794  59154196               2226
# 471795  59154196               2227
# 471816  59154196               2248
# 471873  59154196               2607
# 471884  59154196               2620
#
#                                       CHARACTERISTIC_NAME  \
# 2           Average total income in 2020 among recipie...
# 25                               Government transfers (%)
# 55          Average total income of household in 2020 ($)
# 82                                 Non-official languages
# 104                                   Indigenous identity
# ...                                                   ...
# 471794                                         Unemployed
# 471795                            Not in the labour force
# 471816                                    All occupations
# 471873                                     Public transit
# 471884                       Between 7 a.m. and 7:59 a.m.
#
#         CHARACTERISTIC_NOTE  C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  \
# 2                       NaN         63400.0        77000.0          48400.0
# 25                     20.0            12.7            9.2             19.2
# 55                      NaN        133000.0            NaN              NaN
# 82                      NaN           250.0          120.0            135.0
# 104                    45.0            10.0            0.0             10.0
# ...                     ...             ...            ...              ...
# 471794                  NaN            55.0           20.0             30.0
# 471795                  NaN           225.0           95.0            135.0
# 471816                191.0           485.0          270.0            215.0
# 471873                  NaN           120.0           45.0             75.0
# 471884                  NaN           110.0           70.0             40.0
#
#         C10_RATE_TOTAL  C11_RATE_MEN+  C12_RATE_WOMEN+ Unnamed: 14
# 2              63400.0        77000.0          48400.0         NaN
# 25                12.7            9.2             19.2         NaN
# 55            133000.0            NaN              NaN         NaN
# 82                35.0           32.9             39.1         NaN
# 104                1.4            0.0              2.9         NaN
# ...                ...            ...              ...         ...
# 471794             NaN            NaN              NaN         NaN
# 471795             NaN            NaN              NaN         NaN
# 471816            96.0          100.0             93.5         NaN
# 471873            32.4           22.0             44.1         NaN
# 471884            29.7           34.1             23.5         NaN
#
# [33636 rows x 15 columns]

# %%
filtered_df.to_csv('Selected-variables.csv')

# %% [markdown]
# As the last 'GEO' was repeated twice, we will drop the records that have been duplicated in the dataframe

# %%
filtered_df = filtered_df.drop_duplicates()

# %% [markdown]
# For our pre processing step we only need to consider the following characteristic ids:2223, 2224, 2225, 2226, 2227, 128, 252, 1488

# %%
# Focusing on the data that is needed for the computation 
Considered_df = filtered_df[filtered_df['CHARACTERISTIC_ID'].isin([2223, 2224, 2225, 2226, 2227, 128, 252, 1488])]
Considered_df
# Out:
#         CENSUS_YEAR              DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 2              2021  2021S051259150307      59150307  Dissemination area
# 55             2021  2021S051259150307      59150307  Dissemination area
# 174            2021  2021S051259150307      59150307  Dissemination area
# 396            2021  2021S051259150307      59150307  Dissemination area
# 397            2021  2021S051259150307      59150307  Dissemination area
# ...             ...                ...           ...                 ...
# 471374         2021  2021S051259154196      59154196  Dissemination area
# 471375         2021  2021S051259154196      59154196  Dissemination area
# 471376         2021  2021S051259154196      59154196  Dissemination area
# 471377         2021  2021S051259154196      59154196  Dissemination area
# 471378         2021  2021S051259154196      59154196  Dissemination area
#
#         GEO_NAME  CHARACTERISTIC_ID  \
# 2       59150307                128
# 55      59150307                252
# 174     59150307               1488
# 396     59150307               2223
# 397     59150307               2224
# ...          ...                ...
# 471374  59154196               2223
# 471375  59154196               2224
# 471376  59154196               2225
# 471377  59154196               2226
# 471378  59154196               2227
#
#                                       CHARACTERISTIC_NAME  \
# 2           Average total income in 2020 among recipie...
# 55          Average total income of household in 2020 ($)
# 174                         Median value of dwellings ($)
# 396     Total - Population aged 15 years and over by l...
# 397                                   In the labour force
# ...                                                   ...
# 471374  Total - Population aged 15 years and over by l...
# 471375                                In the labour force
# 471376                                           Employed
# 471377                                         Unemployed
# 471378                            Not in the labour force
#
#         CHARACTERISTIC_NOTE  C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  \
# 2                       NaN         63400.0        77000.0          48400.0
# 55                      NaN        133000.0            NaN              NaN
# 174                    66.0       1700000.0            NaN              NaN
# 396                   184.0           590.0          315.0            275.0
# 397                     NaN           405.0          220.0            185.0
# ...                     ...             ...            ...              ...
# 471374                184.0           730.0          370.0            360.0
# 471375                  NaN           505.0          275.0            225.0
# 471376                  NaN           450.0          255.0            200.0
# 471377                  NaN            55.0           20.0             30.0
# 471378                  NaN           225.0           95.0            135.0
#
#         C10_RATE_TOTAL  C11_RATE_MEN+  C12_RATE_WOMEN+ Unnamed: 14
# 2              63400.0        77000.0          48400.0         NaN
# 55            133000.0            NaN              NaN         NaN
# 174          1700000.0            NaN              NaN         NaN
# 396                NaN            NaN              NaN         NaN
# 397                NaN            NaN              NaN         NaN
# ...                ...            ...              ...         ...
# 471374             NaN            NaN              NaN         NaN
# 471375             NaN            NaN              NaN         NaN
# 471376             NaN            NaN              NaN         NaN
# 471377             NaN            NaN              NaN         NaN
# 471378             NaN            NaN              NaN         NaN
#
# [8053 rows x 15 columns]

# %% [markdown]
# # Computation for labor rates

# %% [markdown]
# We will compute the rates based on the subset of the data. At each time we would filter the data for each specific 'GEO_NAME' and then we would compute the rates based on the data for that 'GEO_NAME'.
#
# In this code we would start from an empty dataframe 'Filled_df' and at each time we would add the data computed for each 'GEO_NAME' to this dataframe at the end of each cycle.
#
# __NOTE:__ in our computation, we would also remove the characteristic that was not needed '2223' from the data of each 'GEO_NAME' and then add the data to our global dataframe.

# %%
# The dataframe that would contain the filled values for the rates
Filled_df = pd.DataFrame()

# We will compute the rates for each 'GEO_NAME' one by one 
for geo in Considered_df['GEO_NAME'].unique(): 
    
    # Take the useful data for the computation of the rate of this 'GEO_NAME'
    One_sample = Considered_df[(Considered_df['GEO_NAME'] == geo) & 
                               Considered_df['CHARACTERISTIC_ID'].isin([2223, 2224, 2225, 2226, 2227])].copy()
    
    # Take the values of the total population 
    Denomenator = One_sample[One_sample['CHARACTERISTIC_ID'] == 2223][['C1_COUNT_TOTAL', 'C2_COUNT_MEN+', 'C3_COUNT_WOMEN+']]
    
    # Take the values of each type of the population 
    Numenator = One_sample[One_sample['CHARACTERISTIC_ID']!= 2223][['C1_COUNT_TOTAL', 'C2_COUNT_MEN+', 'C3_COUNT_WOMEN+']]
    
    # Computing the rates and put them in the corresponding cell
    One_sample[['C10_RATE_TOTAL', 'C11_RATE_MEN+', 'C12_RATE_WOMEN+']] = Numenator.divide(np.array(Denomenator)) * 100
    
    # Removing the chracteristic '2223' that is not needed for us which is the total population 
    One_sample = One_sample[One_sample['CHARACTERISTIC_ID'] != 2223]
    
    # Adding the new data for this 'GEO_NAME' to the temporary dataframe that we created
    Filled_df = pd.concat([Filled_df, One_sample])

# %% [markdown]
# # Scaling some characteristics

# %% [markdown]
# We will scale the values for these characteristics (128, 252, 1488) and then concat the values to the previously filled data frame.

# %%
# The characteristics that should be scaled
Need_to_scale = [128, 252, 1488]

# For each characteristic
for character_id in Need_to_scale: 
    
    # The data regarding this characteristic 
    temp_df = Considered_df[Considered_df['CHARACTERISTIC_ID'] == character_id].copy()
    
    # Taking the values of this characteristic
    data = np.array(temp_df['C1_COUNT_TOTAL'])
    
    # Creating a scaler
    scaler = MinMaxScaler((0, 100))
    
    # Getting the scaled data
    scaled_data = 100 - scaler.fit_transform(data.reshape(-1, 1))
    
    # Put the scaled value in the right column 
    temp_df['C10_RATE_TOTAL'] = scaled_data
    
    # Adding this subset of data to the datframe that we had before
    Filled_df = pd.concat([Filled_df, temp_df])

# %% [markdown]
# After the computations, we would merge the data that was considered and not considered for our computations, in order to get to the initial dataframe (filtered_df), and then sort the values based on the value of the 'GEO_NAME' and the 'CHARACTERISTIC_ID' and resetting the index of the data.

# %%
# The data that has not been considered in the computation
Not_considered_df = filtered_df[~filtered_df['CHARACTERISTIC_ID'].isin([2223, 2224, 2225, 2226, 2227, 128, 252, 1488])].copy()

# Merging the considered and not considered data for the report 
# and sorting the data based on the 'GEO_NAME' and 'CHARACTERISTIC_ID'
Whole_df = pd.concat([Filled_df, Not_considered_df]).sort_values(['GEO_NAME','CHARACTERISTIC_ID']).reset_index(drop = True)

# %% [markdown]
# Taking a look at the final resulf of our data.

# %%
Whole_df
# Out:
#        CENSUS_YEAR              DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 0             2021  2021S051259150307      59150307  Dissemination area
# 1             2021  2021S051259150307      59150307  Dissemination area
# 2             2021  2021S051259150307      59150307  Dissemination area
# 3             2021  2021S051259150307      59150307  Dissemination area
# 4             2021  2021S051259150307      59150307  Dissemination area
# ...            ...                ...           ...                 ...
# 32576         2021  2021S051259154196      59154196  Dissemination area
# 32577         2021  2021S051259154196      59154196  Dissemination area
# 32578         2021  2021S051259154196      59154196  Dissemination area
# 32579         2021  2021S051259154196      59154196  Dissemination area
# 32580         2021  2021S051259154196      59154196  Dissemination area
#
#        GEO_NAME  CHARACTERISTIC_ID  \
# 0      59150307                128
# 1      59150307                151
# 2      59150307                252
# 3      59150307               1082
# 4      59150307               1403
# ...         ...                ...
# 32576  59154196               2226
# 32577  59154196               2227
# 32578  59154196               2248
# 32579  59154196               2607
# 32580  59154196               2620
#
#                                      CHARACTERISTIC_NAME  CHARACTERISTIC_NOTE  \
# 0          Average total income in 2020 among recipie...                  NaN
# 1                               Government transfers (%)                 20.0
# 2          Average total income of household in 2020 ($)                  NaN
# 3                                 Non-official languages                  NaN
# 4                                    Indigenous identity                 45.0
# ...                                                  ...                  ...
# 32576                                         Unemployed                  NaN
# 32577                            Not in the labour force                  NaN
# 32578                                    All occupations                191.0
# 32579                                     Public transit                  NaN
# 32580                       Between 7 a.m. and 7:59 a.m.                  NaN
#
#        C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  C10_RATE_TOTAL  \
# 0             63400.0        77000.0          48400.0       92.436798
# 1                12.7            9.2             19.2       12.700000
# 2            133000.0            NaN              NaN       89.469437
# 3               250.0          120.0            135.0       35.000000
# 4                10.0            0.0             10.0        1.400000
# ...               ...            ...              ...             ...
# 32576            55.0           20.0             30.0        7.534247
# 32577           225.0           95.0            135.0       30.821918
# 32578           485.0          270.0            215.0       96.000000
# 32579           120.0           45.0             75.0       32.400000
# 32580           110.0           70.0             40.0       29.700000
#
#        C11_RATE_MEN+  C12_RATE_WOMEN+ Unnamed: 14
# 0       77000.000000     48400.000000         NaN
# 1           9.200000        19.200000         NaN
# 2                NaN              NaN         NaN
# 3          32.900000        39.100000         NaN
# 4           0.000000         2.900000         NaN
# ...              ...              ...         ...
# 32576       5.405405         8.333333         NaN
# 32577      25.675676        37.500000         NaN
# 32578     100.000000        93.500000         NaN
# 32579      22.000000        44.100000         NaN
# 32580      34.100000        23.500000         NaN
#
# [32581 rows x 15 columns]

# %% [markdown]
# Taking a look at the final computation that was done for each 'GEO_NAME' to verify the computation of the rates.

# %%
Whole_df[Whole_df['CHARACTERISTIC_ID'].isin([2223, 2224, 2225, 2226, 2227, 128, 252, 1488])]
# Out:
#        CENSUS_YEAR              DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 0             2021  2021S051259150307      59150307  Dissemination area
# 2             2021  2021S051259150307      59150307  Dissemination area
# 17            2021  2021S051259150307      59150307  Dissemination area
# 27            2021  2021S051259150307      59150307  Dissemination area
# 28            2021  2021S051259150307      59150307  Dissemination area
# ...            ...                ...           ...                 ...
# 32564         2021  2021S051259154196      59154196  Dissemination area
# 32574         2021  2021S051259154196      59154196  Dissemination area
# 32575         2021  2021S051259154196      59154196  Dissemination area
# 32576         2021  2021S051259154196      59154196  Dissemination area
# 32577         2021  2021S051259154196      59154196  Dissemination area
#
#        GEO_NAME  CHARACTERISTIC_ID  \
# 0      59150307                128
# 2      59150307                252
# 17     59150307               1488
# 27     59150307               2224
# 28     59150307               2225
# ...         ...                ...
# 32564  59154196               1488
# 32574  59154196               2224
# 32575  59154196               2225
# 32576  59154196               2226
# 32577  59154196               2227
#
#                                      CHARACTERISTIC_NAME  CHARACTERISTIC_NOTE  \
# 0          Average total income in 2020 among recipie...                  NaN
# 2          Average total income of household in 2020 ($)                  NaN
# 17                         Median value of dwellings ($)                 66.0
# 27                                   In the labour force                  NaN
# 28                                              Employed                  NaN
# ...                                                  ...                  ...
# 32564                      Median value of dwellings ($)                 66.0
# 32574                                In the labour force                  NaN
# 32575                                           Employed                  NaN
# 32576                                         Unemployed                  NaN
# 32577                            Not in the labour force                  NaN
#
#        C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  C10_RATE_TOTAL  \
# 0             63400.0        77000.0          48400.0       92.436798
# 2            133000.0            NaN              NaN       89.469437
# 17          1700000.0            NaN              NaN       82.547170
# 27              405.0          220.0            185.0       68.644068
# 28              360.0          195.0            170.0       61.016949
# ...               ...            ...              ...             ...
# 32564       2000000.0            NaN              NaN       78.616352
# 32574           505.0          275.0            225.0       69.178082
# 32575           450.0          255.0            200.0       61.643836
# 32576            55.0           20.0             30.0        7.534247
# 32577           225.0           95.0            135.0       30.821918
#
#        C11_RATE_MEN+  C12_RATE_WOMEN+ Unnamed: 14
# 0       77000.000000     48400.000000         NaN
# 2                NaN              NaN         NaN
# 17               NaN              NaN         NaN
# 27         69.841270        67.272727         NaN
# 28         61.904762        61.818182         NaN
# ...              ...              ...         ...
# 32564            NaN              NaN         NaN
# 32574      74.324324        62.500000         NaN
# 32575      68.918919        55.555556         NaN
# 32576       5.405405         8.333333         NaN
# 32577      25.675676        37.500000         NaN
#
# [7030 rows x 15 columns]

# %% [markdown]
# ## Final value

# %% [markdown]
# Here we will only keep the necessary value that we want from each characteristic. We will add another column to put the final value that we want from each characteristic.
#
# For each characteristic except the followings we need the value of 'C10_RATE_TOTAL'

# %% [markdown]
#     Unemployed: 'C10_RATE_TOTAL'
#
#     Employed: 'C12_RATE_WOMEN+'
#
#     Not in the laybor force: 'C11_RATE_MEN'
#
#     In the laybor force: 'C12_RATE_WOMEN+'

# %% [markdown]
# ### Function final value

# %% [markdown]
# We will write another function that based on the type of the characteristic, would take the correct final value of that characteristic.

# %%
# This given one row, would output a specific value 
def final_value(x): 
    
    # If the characteristic id is 2225 or 2224 we need the rate for women 
    if x['CHARACTERISTIC_ID'] in [2225, 2224]: 
        return x['C12_RATE_WOMEN+']
    
    # If the characteristic id is 2227 we need the rate of the men
    elif x['CHARACTERISTIC_ID'] == 2227: 
        return x['C11_RATE_MEN+']

    # In all of other cases we need the value of the rate total 
    else: 
        return x['C10_RATE_TOTAL']
    
# Forming the final value 
Whole_df['Final value'] = Whole_df.apply(final_value, axis = 1)

# %% [markdown]
# Taking a look at the output for the final value and verify the final values.

# %%
Whole_df[Whole_df['CHARACTERISTIC_ID'].isin([2223, 2224, 2225, 2226, 2227, 128, 252, 1488])]
# Out:
#        CENSUS_YEAR              DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 0             2021  2021S051259150307      59150307  Dissemination area
# 2             2021  2021S051259150307      59150307  Dissemination area
# 17            2021  2021S051259150307      59150307  Dissemination area
# 27            2021  2021S051259150307      59150307  Dissemination area
# 28            2021  2021S051259150307      59150307  Dissemination area
# ...            ...                ...           ...                 ...
# 32564         2021  2021S051259154196      59154196  Dissemination area
# 32574         2021  2021S051259154196      59154196  Dissemination area
# 32575         2021  2021S051259154196      59154196  Dissemination area
# 32576         2021  2021S051259154196      59154196  Dissemination area
# 32577         2021  2021S051259154196      59154196  Dissemination area
#
#        GEO_NAME  CHARACTERISTIC_ID  \
# 0      59150307                128
# 2      59150307                252
# 17     59150307               1488
# 27     59150307               2224
# 28     59150307               2225
# ...         ...                ...
# 32564  59154196               1488
# 32574  59154196               2224
# 32575  59154196               2225
# 32576  59154196               2226
# 32577  59154196               2227
#
#                                      CHARACTERISTIC_NAME  CHARACTERISTIC_NOTE  \
# 0          Average total income in 2020 among recipie...                  NaN
# 2          Average total income of household in 2020 ($)                  NaN
# 17                         Median value of dwellings ($)                 66.0
# 27                                   In the labour force                  NaN
# 28                                              Employed                  NaN
# ...                                                  ...                  ...
# 32564                      Median value of dwellings ($)                 66.0
# 32574                                In the labour force                  NaN
# 32575                                           Employed                  NaN
# 32576                                         Unemployed                  NaN
# 32577                            Not in the labour force                  NaN
#
#        C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  C10_RATE_TOTAL  \
# 0             63400.0        77000.0          48400.0       92.436798
# 2            133000.0            NaN              NaN       89.469437
# 17          1700000.0            NaN              NaN       82.547170
# 27              405.0          220.0            185.0       68.644068
# 28              360.0          195.0            170.0       61.016949
# ...               ...            ...              ...             ...
# 32564       2000000.0            NaN              NaN       78.616352
# 32574           505.0          275.0            225.0       69.178082
# 32575           450.0          255.0            200.0       61.643836
# 32576            55.0           20.0             30.0        7.534247
# 32577           225.0           95.0            135.0       30.821918
#
#        C11_RATE_MEN+  C12_RATE_WOMEN+ Unnamed: 14  Final value
# 0       77000.000000     48400.000000         NaN    92.436798
# 2                NaN              NaN         NaN    89.469437
# 17               NaN              NaN         NaN    82.547170
# 27         69.841270        67.272727         NaN    67.272727
# 28         61.904762        61.818182         NaN    61.818182
# ...              ...              ...         ...          ...
# 32564            NaN              NaN         NaN    78.616352
# 32574      74.324324        62.500000         NaN    62.500000
# 32575      68.918919        55.555556         NaN    55.555556
# 32576       5.405405         8.333333         NaN     7.534247
# 32577      25.675676        37.500000         NaN    25.675676
#
# [7030 rows x 16 columns]

# %% [markdown]
# Here we will drop the meaningless column that we had.

# %% [markdown]
# ## Pivoting

# %% [markdown]
# Now we are ready to pivot the dataframe where in the columns we will find the different characteristics and in the rows we would have the 'DGUID'

# %%
pivot_df = Whole_df.pivot(index='GEO_NAME', columns='CHARACTERISTIC_NAME', values='Final value')
pivot_df_filled = pivot_df.fillna(0)
pivot_df_filled
# Out:
# CHARACTERISTIC_NAME      Average total income in 2020 among recipients ($)  \
# GEO_NAME
# 59150307                                                     92.436798
# 59150308                                                     91.891325
# 59150309                                                     94.073219
# 59150310                                                     94.996329
# 59150311                                                     95.206126
# ...                                                                ...
# 59154192                                                     86.016994
# 59154193                                                     90.548621
# 59154194                                                     95.415924
# 59154195                                                     96.548830
# 59154196                                                     96.380992
#
# CHARACTERISTIC_NAME      Employed      Unemployed    1960 or before  \
# GEO_NAME
# 59150307                61.818182        6.779661              38.9
# 59150308                68.085106        4.255319              68.2
# 59150309                70.000000        3.636364              38.5
# 59150310                74.626866        8.396947              20.3
# 59150311                52.631579       10.843373              36.1
# ...                           ...             ...               ...
# 59154192                63.440860        4.444444               3.0
# 59154193                73.809524        4.678363               5.9
# 59154194                45.161290        7.142857               6.5
# 59154195                43.076923        7.874016              12.5
# 59154196                55.555556        7.534247               9.3
#
# CHARACTERISTIC_NAME    1961 to 1980    1981 to 1990    1991 to 2000  \
# GEO_NAME
# 59150307                       16.7             3.7            18.5
# 59150308                        6.8             4.5             6.8
# 59150309                        9.6             5.8             5.8
# 59150310                       29.1             3.8             5.1
# 59150311                       11.1            11.1            16.7
# ...                             ...             ...             ...
# 59154192                       24.8            53.5             9.9
# 59154193                       31.4            52.0             7.8
# 59154194                       21.7            30.4            13.0
# 59154195                       20.8            18.8            20.8
# 59154196                       20.4            18.5            20.4
#
# CHARACTERISTIC_NAME    5 to 14 years    65 to 74 years    75 to 84 years  ...  \
# GEO_NAME                                                                  ...
# 59150307                        23.7              11.1              11.1  ...
# 59150308                        21.9              18.2               4.5  ...
# 59150309                         9.5              13.5               3.8  ...
# 59150310                        17.9               3.8               0.0  ...
# 59150311                        19.4              22.2               8.3  ...
# ...                              ...               ...               ...  ...
# 59154192                        19.0              11.9               6.9  ...
# 59154193                        18.2              11.8               3.9  ...
# 59154194                        15.9              13.0               0.0  ...
# 59154195                        13.4              18.8               6.3  ...
# 59154196                         8.9              14.8              11.1  ...
#
# CHARACTERISTIC_NAME    Not in the labour force    One-maintainer household  \
# GEO_NAME
# 59150307                             30.158730                        51.9
# 59150308                             30.434783                        50.0
# 59150309                             28.813559                        40.4
# 59150310                             14.062500                        60.8
# 59150311                             35.555556                        52.8
# ...                                        ...                         ...
# 59154192                             24.137931                        56.4
# 59154193                             24.137931                        48.0
# 59154194                             28.000000                        43.5
# 59154195                             35.483871                        43.8
# 59154196                             25.675676                        35.2
#
# CHARACTERISTIC_NAME    Postsecondary certificate, diploma or degree  \
# GEO_NAME
# 59150307                                                       60.2
# 59150308                                                       64.9
# 59150309                                                       58.7
# 59150310                                                       62.6
# 59150311                                                       49.4
# ...                                                             ...
# 59154192                                                       87.2
# 59154193                                                       82.5
# 59154194                                                       49.1
# 59154195                                                       53.2
# 59154196                                                       44.5
#
# CHARACTERISTIC_NAME    Public transit    Renter    South Asian, n.o.s.  \
# GEO_NAME
# 59150307                         11.5      27.8                    0.0
# 59150308                         14.6      29.5                    0.0
# 59150309                         29.5      38.5                    0.0
# 59150310                         38.9      78.5                    0.0
# 59150311                         17.1      44.4                    0.0
# ...                               ...       ...                    ...
# 59154192                          6.3       9.9                    0.0
# 59154193                         14.5      56.9                    0.0
# 59154194                         26.9      56.5                    3.7
# 59154195                         15.2      39.6                    0.0
# 59154196                         32.4      38.9                    0.0
#
# CHARACTERISTIC_NAME    Spending 30% or more of income on shelter costs  \
# GEO_NAME
# 59150307                                                          22.6
# 59150308                                                          26.7
# 59150309                                                          23.1
# 59150310                                                          44.3
# 59150311                                                          30.6
# ...                                                                ...
# 59154192                                                          24.0
# 59154193                                                          23.5
# 59154194                                                          26.1
# 59154195                                                          20.8
# 59154196                                                          27.3
#
# CHARACTERISTIC_NAME    Total visible minority population    Under 5 years  \
# GEO_NAME
# 59150307                                            33.1             10.5
# 59150308                                            33.6             21.9
# 59150309                                            45.3              4.8
# 59150310                                            40.9              7.7
# 59150311                                            64.9              0.0
# ...                                                  ...              ...
# 59154192                                            23.2              9.5
# 59154193                                            24.9             10.9
# 59154194                                            64.2              7.2
# 59154195                                            91.2              2.4
# 59154196                                            90.2              5.9
#
# CHARACTERISTIC_NAME  Average number of rooms per dwelling
# GEO_NAME
# 59150307                                              7.2
# 59150308                                              6.5
# 59150309                                              5.4
# 59150310                                              3.3
# 59150311                                              6.0
# ...                                                   ...
# 59154192                                              4.7
# 59154193                                              3.7
# 59154194                                              5.2
# 59154195                                              5.8
# 59154196                                              6.6
#
# [1023 rows x 38 columns]

# %% [markdown]
# ## Final preprocessing

# %% [markdown]
# In this section we would perform the final preprocessing steps in the data. Here we will update the rates for a specific characterstic and merge some characteristic to construct a new one.

# %% [markdown]
# ## Postsecondary rate update.

# %% [markdown]
# The previous version of the values is:

# %%
pivot_df['  Postsecondary certificate, diploma or degree']
# Out:
# GEO_NAME
# 59150307    60.2
# 59150308    64.9
# 59150309    58.7
# 59150310    62.6
# 59150311    49.4
#             ...
# 59154192    87.2
# 59154193    82.5
# 59154194    49.1
# 59154195    53.2
# 59154196    44.5
# Name:   Postsecondary certificate, diploma or degree, Length: 1023, dtype: float64

# %%
# Updating the values 
pivot_df['  Postsecondary certificate, diploma or degree'] = 100 - pivot_df['  Postsecondary certificate, diploma or degree']
pivot_df['  Postsecondary certificate, diploma or degree']
# Out:
# GEO_NAME
# 59150307    39.8
# 59150308    35.1
# 59150309    41.3
# 59150310    37.4
# 59150311    50.6
#             ...
# 59154192    12.8
# 59154193    17.5
# 59154194    50.9
# 59154195    46.8
# 59154196    55.5
# Name:   Postsecondary certificate, diploma or degree, Length: 1023, dtype: float64

# %% [markdown]
# ## Columns aggregate: 2000 and before

# %%
# Forming the new column
pivot_df_filled['2000 and before'] = pivot_df_filled[['  1960 or before', '  1961 to 1980', '  1981 to 1990', '  1991 to 2000']].sum(axis = 1)

# Removing the previous columns from the data 
pivot_df_filled.drop(['  1960 or before', '  1961 to 1980', '  1981 to 1990', '  1991 to 2000'], axis = 1, inplace = True)
pivot_df_filled
# Out:
# CHARACTERISTIC_NAME      Average total income in 2020 among recipients ($)  \
# GEO_NAME
# 59150307                                                     92.436798
# 59150308                                                     91.891325
# 59150309                                                     94.073219
# 59150310                                                     94.996329
# 59150311                                                     95.206126
# ...                                                                ...
# 59154192                                                     86.016994
# 59154193                                                     90.548621
# 59154194                                                     95.415924
# 59154195                                                     96.548830
# 59154196                                                     96.380992
#
# CHARACTERISTIC_NAME      Employed      Unemployed    5 to 14 years  \
# GEO_NAME
# 59150307                61.818182        6.779661             23.7
# 59150308                68.085106        4.255319             21.9
# 59150309                70.000000        3.636364              9.5
# 59150310                74.626866        8.396947             17.9
# 59150311                52.631579       10.843373             19.4
# ...                           ...             ...              ...
# 59154192                63.440860        4.444444             19.0
# 59154193                73.809524        4.678363             18.2
# 59154194                45.161290        7.142857             15.9
# 59154195                43.076923        7.874016             13.4
# 59154196                55.555556        7.534247              8.9
#
# CHARACTERISTIC_NAME    65 to 74 years    75 to 84 years    85 years and over  \
# GEO_NAME
# 59150307                         11.1              11.1                  5.6
# 59150308                         18.2               4.5                  9.1
# 59150309                         13.5               3.8                  0.0
# 59150310                          3.8               0.0                  2.5
# 59150311                         22.2               8.3                  0.0
# ...                               ...               ...                  ...
# 59154192                         11.9               6.9                  3.0
# 59154193                         11.8               3.9                  0.0
# 59154194                         13.0               0.0                  8.7
# 59154195                         18.8               6.3                  4.2
# 59154196                         14.8              11.1                  5.6
#
# CHARACTERISTIC_NAME    African American    All occupations  \
# GEO_NAME
# 59150307                            0.0               96.3
# 59150308                            0.0              100.0
# 59150309                            0.0               96.1
# 59150310                            0.0               99.1
# 59150311                            0.0               96.2
# ...                                 ...                ...
# 59154192                            0.0              100.0
# 59154193                            0.0               99.2
# 59154194                            0.0               98.6
# 59154195                            0.0               97.3
# 59154196                            0.0               96.0
#
# CHARACTERISTIC_NAME    Average total income of household in 2020 ($)  ...  \
# GEO_NAME                                                              ...
# 59150307                                                   89.469437  ...
# 59150308                                                   89.671172  ...
# 59150309                                                   91.285051  ...
# 59150310                                                   94.452290  ...
# 59150311                                                   91.285051  ...
# ...                                                              ...  ...
# 59154192                                                   86.645148  ...
# 59154193                                                   90.861408  ...
# 59154194                                                   91.184184  ...
# 59154195                                                   91.991124  ...
# 59154196                                                   90.982449  ...
#
# CHARACTERISTIC_NAME    One-maintainer household  \
# GEO_NAME
# 59150307                                   51.9
# 59150308                                   50.0
# 59150309                                   40.4
# 59150310                                   60.8
# 59150311                                   52.8
# ...                                         ...
# 59154192                                   56.4
# 59154193                                   48.0
# 59154194                                   43.5
# 59154195                                   43.8
# 59154196                                   35.2
#
# CHARACTERISTIC_NAME    Postsecondary certificate, diploma or degree  \
# GEO_NAME
# 59150307                                                       60.2
# 59150308                                                       64.9
# 59150309                                                       58.7
# 59150310                                                       62.6
# 59150311                                                       49.4
# ...                                                             ...
# 59154192                                                       87.2
# 59154193                                                       82.5
# 59154194                                                       49.1
# 59154195                                                       53.2
# 59154196                                                       44.5
#
# CHARACTERISTIC_NAME    Public transit    Renter    South Asian, n.o.s.  \
# GEO_NAME
# 59150307                         11.5      27.8                    0.0
# 59150308                         14.6      29.5                    0.0
# 59150309                         29.5      38.5                    0.0
# 59150310                         38.9      78.5                    0.0
# 59150311                         17.1      44.4                    0.0
# ...                               ...       ...                    ...
# 59154192                          6.3       9.9                    0.0
# 59154193                         14.5      56.9                    0.0
# 59154194                         26.9      56.5                    3.7
# 59154195                         15.2      39.6                    0.0
# 59154196                         32.4      38.9                    0.0
#
# CHARACTERISTIC_NAME    Spending 30% or more of income on shelter costs  \
# GEO_NAME
# 59150307                                                          22.6
# 59150308                                                          26.7
# 59150309                                                          23.1
# 59150310                                                          44.3
# 59150311                                                          30.6
# ...                                                                ...
# 59154192                                                          24.0
# 59154193                                                          23.5
# 59154194                                                          26.1
# 59154195                                                          20.8
# 59154196                                                          27.3
#
# CHARACTERISTIC_NAME    Total visible minority population    Under 5 years  \
# GEO_NAME
# 59150307                                            33.1             10.5
# 59150308                                            33.6             21.9
# 59150309                                            45.3              4.8
# 59150310                                            40.9              7.7
# 59150311                                            64.9              0.0
# ...                                                  ...              ...
# 59154192                                            23.2              9.5
# 59154193                                            24.9             10.9
# 59154194                                            64.2              7.2
# 59154195                                            91.2              2.4
# 59154196                                            90.2              5.9
#
# CHARACTERISTIC_NAME  Average number of rooms per dwelling  2000 and before
# GEO_NAME
# 59150307                                              7.2             77.8
# 59150308                                              6.5             86.3
# 59150309                                              5.4             59.7
# 59150310                                              3.3             58.3
# 59150311                                              6.0             75.0
# ...                                                   ...              ...
# 59154192                                              4.7             91.2
# 59154193                                              3.7             97.1
# 59154194                                              5.2             71.6
# 59154195                                              5.8             72.9
# 59154196                                              6.6             68.6
#
# [1023 rows x 35 columns]

# %% [markdown]
# ## Columns aggregate: 65 year and over

# %%
# Forming the new column
pivot_df_filled['65 years and over'] = pivot_df_filled[['  65 to 74 years', '  75 to 84 years', '  85 years and over']].sum(axis = 1)

# Removing the previous columns from the data 
pivot_df_filled.drop(['  65 to 74 years', '  75 to 84 years', '  85 years and over'], axis = 1, inplace = True)
pivot_df_filled
# Out:
# CHARACTERISTIC_NAME      Average total income in 2020 among recipients ($)  \
# GEO_NAME
# 59150307                                                     92.436798
# 59150308                                                     91.891325
# 59150309                                                     94.073219
# 59150310                                                     94.996329
# 59150311                                                     95.206126
# ...                                                                ...
# 59154192                                                     86.016994
# 59154193                                                     90.548621
# 59154194                                                     95.415924
# 59154195                                                     96.548830
# 59154196                                                     96.380992
#
# CHARACTERISTIC_NAME      Employed      Unemployed    5 to 14 years  \
# GEO_NAME
# 59150307                61.818182        6.779661             23.7
# 59150308                68.085106        4.255319             21.9
# 59150309                70.000000        3.636364              9.5
# 59150310                74.626866        8.396947             17.9
# 59150311                52.631579       10.843373             19.4
# ...                           ...             ...              ...
# 59154192                63.440860        4.444444             19.0
# 59154193                73.809524        4.678363             18.2
# 59154194                45.161290        7.142857             15.9
# 59154195                43.076923        7.874016             13.4
# 59154196                55.555556        7.534247              8.9
#
# CHARACTERISTIC_NAME    African American    All occupations  \
# GEO_NAME
# 59150307                            0.0               96.3
# 59150308                            0.0              100.0
# 59150309                            0.0               96.1
# 59150310                            0.0               99.1
# 59150311                            0.0               96.2
# ...                                 ...                ...
# 59154192                            0.0              100.0
# 59154193                            0.0               99.2
# 59154194                            0.0               98.6
# 59154195                            0.0               97.3
# 59154196                            0.0               96.0
#
# CHARACTERISTIC_NAME    Average total income of household in 2020 ($)  \
# GEO_NAME
# 59150307                                                   89.469437
# 59150308                                                   89.671172
# 59150309                                                   91.285051
# 59150310                                                   94.452290
# 59150311                                                   91.285051
# ...                                                              ...
# 59154192                                                   86.645148
# 59154193                                                   90.861408
# 59154194                                                   91.184184
# 59154195                                                   91.991124
# 59154196                                                   90.982449
#
# CHARACTERISTIC_NAME    Between 7 a.m. and 7:59 a.m.    Black, n.o.s.  \
# GEO_NAME
# 59150307                                       23.1              0.0
# 59150308                                       17.1              0.0
# 59150309                                       18.2              0.0
# 59150310                                       23.6              0.0
# 59150311                                       20.0              0.0
# ...                                             ...              ...
# 59154192                                       20.6              0.0
# 59154193                                       23.2              0.0
# 59154194                                       21.2              0.0
# 59154195                                       30.4              0.0
# 59154196                                       29.7              0.0
#
# CHARACTERISTIC_NAME    Caucasian (White), n.o.s.  ...  \
# GEO_NAME                                          ...
# 59150307                                     0.0  ...
# 59150308                                     0.0  ...
# 59150309                                     1.6  ...
# 59150310                                     2.0  ...
# 59150311                                     0.0  ...
# ...                                          ...  ...
# 59154192                                     3.8  ...
# 59154193                                     0.0  ...
# 59154194                                     0.0  ...
# 59154195                                     0.0  ...
# 59154196                                     0.0  ...
#
# CHARACTERISTIC_NAME    Postsecondary certificate, diploma or degree  \
# GEO_NAME
# 59150307                                                       60.2
# 59150308                                                       64.9
# 59150309                                                       58.7
# 59150310                                                       62.6
# 59150311                                                       49.4
# ...                                                             ...
# 59154192                                                       87.2
# 59154193                                                       82.5
# 59154194                                                       49.1
# 59154195                                                       53.2
# 59154196                                                       44.5
#
# CHARACTERISTIC_NAME    Public transit    Renter    South Asian, n.o.s.  \
# GEO_NAME
# 59150307                         11.5      27.8                    0.0
# 59150308                         14.6      29.5                    0.0
# 59150309                         29.5      38.5                    0.0
# 59150310                         38.9      78.5                    0.0
# 59150311                         17.1      44.4                    0.0
# ...                               ...       ...                    ...
# 59154192                          6.3       9.9                    0.0
# 59154193                         14.5      56.9                    0.0
# 59154194                         26.9      56.5                    3.7
# 59154195                         15.2      39.6                    0.0
# 59154196                         32.4      38.9                    0.0
#
# CHARACTERISTIC_NAME    Spending 30% or more of income on shelter costs  \
# GEO_NAME
# 59150307                                                          22.6
# 59150308                                                          26.7
# 59150309                                                          23.1
# 59150310                                                          44.3
# 59150311                                                          30.6
# ...                                                                ...
# 59154192                                                          24.0
# 59154193                                                          23.5
# 59154194                                                          26.1
# 59154195                                                          20.8
# 59154196                                                          27.3
#
# CHARACTERISTIC_NAME    Total visible minority population    Under 5 years  \
# GEO_NAME
# 59150307                                            33.1             10.5
# 59150308                                            33.6             21.9
# 59150309                                            45.3              4.8
# 59150310                                            40.9              7.7
# 59150311                                            64.9              0.0
# ...                                                  ...              ...
# 59154192                                            23.2              9.5
# 59154193                                            24.9             10.9
# 59154194                                            64.2              7.2
# 59154195                                            91.2              2.4
# 59154196                                            90.2              5.9
#
# CHARACTERISTIC_NAME  Average number of rooms per dwelling  2000 and before  \
# GEO_NAME
# 59150307                                              7.2             77.8
# 59150308                                              6.5             86.3
# 59150309                                              5.4             59.7
# 59150310                                              3.3             58.3
# 59150311                                              6.0             75.0
# ...                                                   ...              ...
# 59154192                                              4.7             91.2
# 59154193                                              3.7             97.1
# 59154194                                              5.2             71.6
# 59154195                                              5.8             72.9
# 59154196                                              6.6             68.6
#
# CHARACTERISTIC_NAME  65 years and over
# GEO_NAME
# 59150307                          27.8
# 59150308                          31.8
# 59150309                          17.3
# 59150310                           6.3
# 59150311                          30.5
# ...                                ...
# 59154192                          21.8
# 59154193                          15.7
# 59154194                          21.7
# 59154195                          29.3
# 59154196                          31.5
#
# [1023 rows x 33 columns]

# %% [markdown]
# Then we can look at the final versoin of the data:

# %%
pivot_df_filled.to_csv('pivot_df-test.csv')

# %% [markdown]
# # Correlation matrix

# %%
corr_matrix = pivot_df_filled.corr().round(2)
corr_matrix
# Out:
# CHARACTERISTIC_NAME                                     Average total income in 2020 among recipients ($)  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                                               1.00
#     Employed                                                                                     0.06
#     Unemployed                                                                                   0.11
#   5 to 14 years                                                                                 -0.01
#   African American                                                                               0.02
#   All occupations                                                                                0.16
#   Average total income of household in 2020 ($)                                                  0.98
#   Between 7 a.m. and 7:59 a.m.                                                                   0.09
#   Black, n.o.s.                                                                                  0.02
#   Caucasian (White), n.o.s.                                                                      0.01
#   Chinese                                                                                        0.06
#   Filipino                                                                                       0.22
#   Government transfers (%)                                                                       0.48
#   In the labour force                                                                            0.08
#   Indigenous identity                                                                            0.03
#   Major repairs needed                                                                           0.02
#   Median value of dwellings ($)                                                                  0.24
#   Movers                                                                                        -0.05
#   No certificate, diploma or degree                                                              0.13
#   No high school diploma or equivalency certifi...                                               0.13
#   Non-official languages                                                                         0.19
#   Not in the labour force                                                                       -0.04
#   One-maintainer household                                                                      -0.10
#   Postsecondary certificate, diploma or degree                                                  -0.13
#   Public transit                                                                                 0.29
#   Renter                                                                                         0.04
#   South Asian, n.o.s.                                                                            0.04
#   Spending 30% or more of income on shelter costs                                                0.26
#   Total visible minority population                                                              0.20
#   Under 5 years                                                                                  0.00
# Average number of rooms per dwelling                                                            -0.05
# 2000 and before                                                                                  0.00
# 65 years and over                                                                               -0.06
#
# CHARACTERISTIC_NAME                                     Employed  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...          0.06
#     Employed                                                1.00
#     Unemployed                                              0.01
#   5 to 14 years                                             0.05
#   African American                                          0.03
#   All occupations                                           0.30
#   Average total income of household in 2020 ($)             0.15
#   Between 7 a.m. and 7:59 a.m.                              0.21
#   Black, n.o.s.                                             0.07
#   Caucasian (White), n.o.s.                                 0.26
#   Chinese                                                  -0.55
#   Filipino                                                  0.03
#   Government transfers (%)                                 -0.32
#   In the labour force                                       0.96
#   Indigenous identity                                       0.02
#   Major repairs needed                                      0.10
#   Median value of dwellings ($)                             0.26
#   Movers                                                    0.44
#   No certificate, diploma or degree                        -0.48
#   No high school diploma or equivalency certifi...         -0.46
#   Non-official languages                                   -0.44
#   Not in the labour force                                  -0.73
#   One-maintainer household                                  0.11
#   Postsecondary certificate, diploma or degree              0.47
#   Public transit                                            0.10
#   Renter                                                    0.37
#   South Asian, n.o.s.                                       0.02
#   Spending 30% or more of income on shelter costs           0.08
#   Total visible minority population                        -0.42
#   Under 5 years                                             0.06
# Average number of rooms per dwelling                       -0.45
# 2000 and before                                             0.02
# 65 years and over                                          -0.66
#
# CHARACTERISTIC_NAME                                     Unemployed  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...            0.11
#     Employed                                                  0.01
#     Unemployed                                                1.00
#   5 to 14 years                                              -0.04
#   African American                                            0.03
#   All occupations                                            -0.18
#   Average total income of household in 2020 ($)               0.14
#   Between 7 a.m. and 7:59 a.m.                                0.06
#   Black, n.o.s.                                               0.04
#   Caucasian (White), n.o.s.                                   0.08
#   Chinese                                                    -0.11
#   Filipino                                                    0.07
#   Government transfers (%)                                    0.24
#   In the labour force                                         0.21
#   Indigenous identity                                         0.15
#   Major repairs needed                                        0.13
#   Median value of dwellings ($)                              -0.02
#   Movers                                                      0.10
#   No certificate, diploma or degree                           0.06
#   No high school diploma or equivalency certifi...            0.07
#   Non-official languages                                     -0.02
#   Not in the labour force                                    -0.14
#   One-maintainer household                                    0.16
#   Postsecondary certificate, diploma or degree               -0.10
#   Public transit                                              0.22
#   Renter                                                      0.27
#   South Asian, n.o.s.                                         0.02
#   Spending 30% or more of income on shelter costs             0.06
#   Total visible minority population                          -0.01
#   Under 5 years                                              -0.02
# Average number of rooms per dwelling                         -0.23
# 2000 and before                                               0.07
# 65 years and over                                            -0.17
#
# CHARACTERISTIC_NAME                                   5 to 14 years  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...            -0.01
#     Employed                                                   0.05
#     Unemployed                                                -0.04
#   5 to 14 years                                                1.00
#   African American                                             0.04
#   All occupations                                              0.02
#   Average total income of household in 2020 ($)               -0.01
#   Between 7 a.m. and 7:59 a.m.                                 0.04
#   Black, n.o.s.                                                0.02
#   Caucasian (White), n.o.s.                                    0.02
#   Chinese                                                      0.03
#   Filipino                                                    -0.13
#   Government transfers (%)                                    -0.20
#   In the labour force                                          0.03
#   Indigenous identity                                         -0.05
#   Major repairs needed                                        -0.04
#   Median value of dwellings ($)                                0.06
#   Movers                                                       0.11
#   No certificate, diploma or degree                           -0.20
#   No high school diploma or equivalency certifi...            -0.21
#   Non-official languages                                      -0.09
#   Not in the labour force                                     -0.02
#   One-maintainer household                                     0.02
#   Postsecondary certificate, diploma or degree                 0.18
#   Public transit                                              -0.16
#   Renter                                                      -0.15
#   South Asian, n.o.s.                                         -0.01
#   Spending 30% or more of income on shelter costs              0.12
#   Total visible minority population                           -0.05
#   Under 5 years                                                0.12
# Average number of rooms per dwelling                           0.13
# 2000 and before                                               -0.12
# 65 years and over                                             -0.11
#
# CHARACTERISTIC_NAME                                   African American  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                0.02
#     Employed                                                      0.03
#     Unemployed                                                    0.03
#   5 to 14 years                                                   0.04
#   African American                                                1.00
#   All occupations                                                 0.00
#   Average total income of household in 2020 ($)                   0.03
#   Between 7 a.m. and 7:59 a.m.                                   -0.02
#   Black, n.o.s.                                                  -0.01
#   Caucasian (White), n.o.s.                                       0.02
#   Chinese                                                        -0.08
#   Filipino                                                       -0.05
#   Government transfers (%)                                        0.00
#   In the labour force                                             0.04
#   Indigenous identity                                             0.20
#   Major repairs needed                                            0.05
#   Median value of dwellings ($)                                  -0.07
#   Movers                                                          0.07
#   No certificate, diploma or degree                              -0.02
#   No high school diploma or equivalency certifi...               -0.01
#   Non-official languages                                         -0.08
#   Not in the labour force                                        -0.04
#   One-maintainer household                                        0.06
#   Postsecondary certificate, diploma or degree                    0.03
#   Public transit                                                  0.04
#   Renter                                                          0.05
#   South Asian, n.o.s.                                             0.08
#   Spending 30% or more of income on shelter costs                 0.01
#   Total visible minority population                              -0.08
#   Under 5 years                                                   0.03
# Average number of rooms per dwelling                             -0.06
# 2000 and before                                                   0.04
# 65 years and over                                                -0.02
#
# CHARACTERISTIC_NAME                                   All occupations  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...               0.16
#     Employed                                                     0.30
#     Unemployed                                                  -0.18
#   5 to 14 years                                                  0.02
#   African American                                               0.00
#   All occupations                                                1.00
#   Average total income of household in 2020 ($)                  0.17
#   Between 7 a.m. and 7:59 a.m.                                   0.08
#   Black, n.o.s.                                                 -0.01
#   Caucasian (White), n.o.s.                                      0.06
#   Chinese                                                       -0.23
#   Filipino                                                       0.02
#   Government transfers (%)                                      -0.07
#   In the labour force                                            0.26
#   Indigenous identity                                           -0.02
#   Major repairs needed                                           0.05
#   Median value of dwellings ($)                                  0.14
#   Movers                                                         0.12
#   No certificate, diploma or degree                             -0.32
#   No high school diploma or equivalency certifi...              -0.30
#   Non-official languages                                        -0.16
#   Not in the labour force                                       -0.29
#   One-maintainer household                                      -0.08
#   Postsecondary certificate, diploma or degree                   0.23
#   Public transit                                                 0.04
#   Renter                                                        -0.03
#   South Asian, n.o.s.                                            0.01
#   Spending 30% or more of income on shelter costs                0.05
#   Total visible minority population                             -0.15
#   Under 5 years                                                  0.02
# Average number of rooms per dwelling                             0.00
# 2000 and before                                                 -0.01
# 65 years and over                                               -0.22
#
# CHARACTERISTIC_NAME                                   Average total income of household in 2020 ($)  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                                             0.98
#     Employed                                                                                   0.15
#     Unemployed                                                                                 0.14
#   5 to 14 years                                                                               -0.01
#   African American                                                                             0.03
#   All occupations                                                                              0.17
#   Average total income of household in 2020 ($)                                                1.00
#   Between 7 a.m. and 7:59 a.m.                                                                 0.13
#   Black, n.o.s.                                                                                0.04
#   Caucasian (White), n.o.s.                                                                    0.09
#   Chinese                                                                                     -0.07
#   Filipino                                                                                     0.15
#   Government transfers (%)                                                                     0.44
#   In the labour force                                                                          0.17
#   Indigenous identity                                                                          0.07
#   Major repairs needed                                                                         0.07
#   Median value of dwellings ($)                                                                0.28
#   Movers                                                                                       0.05
#   No certificate, diploma or degree                                                            0.03
#   No high school diploma or equivalency certifi...                                             0.04
#   Non-official languages                                                                       0.07
#   Not in the labour force                                                                     -0.13
#   One-maintainer household                                                                     0.06
#   Postsecondary certificate, diploma or degree                                                -0.01
#   Public transit                                                                               0.27
#   Renter                                                                                       0.18
#   South Asian, n.o.s.                                                                          0.03
#   Spending 30% or more of income on shelter costs                                              0.31
#   Total visible minority population                                                            0.06
#   Under 5 years                                                                                0.01
# Average number of rooms per dwelling                                                          -0.23
# 2000 and before                                                                                0.02
# 65 years and over                                                                             -0.12
#
# CHARACTERISTIC_NAME                                   Between 7 a.m. and 7:59 a.m.  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                            0.09
#     Employed                                                                  0.21
#     Unemployed                                                                0.06
#   5 to 14 years                                                               0.04
#   African American                                                           -0.02
#   All occupations                                                             0.08
#   Average total income of household in 2020 ($)                               0.13
#   Between 7 a.m. and 7:59 a.m.                                                1.00
#   Black, n.o.s.                                                               0.01
#   Caucasian (White), n.o.s.                                                   0.14
#   Chinese                                                                    -0.21
#   Filipino                                                                   -0.05
#   Government transfers (%)                                                   -0.04
#   In the labour force                                                         0.21
#   Indigenous identity                                                         0.04
#   Major repairs needed                                                        0.05
#   Median value of dwellings ($)                                               0.16
#   Movers                                                                      0.09
#   No certificate, diploma or degree                                          -0.15
#   No high school diploma or equivalency certifi...                           -0.15
#   Non-official languages                                                     -0.22
#   Not in the labour force                                                    -0.17
#   One-maintainer household                                                    0.09
#   Postsecondary certificate, diploma or degree                                0.16
#   Public transit                                                             -0.00
#   Renter                                                                      0.11
#   South Asian, n.o.s.                                                        -0.01
#   Spending 30% or more of income on shelter costs                            -0.02
#   Total visible minority population                                          -0.22
#   Under 5 years                                                               0.05
# Average number of rooms per dwelling                                         -0.18
# 2000 and before                                                               0.07
# 65 years and over                                                            -0.07
#
# CHARACTERISTIC_NAME                                   Black, n.o.s.  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...             0.02
#     Employed                                                   0.07
#     Unemployed                                                 0.04
#   5 to 14 years                                                0.02
#   African American                                            -0.01
#   All occupations                                             -0.01
#   Average total income of household in 2020 ($)                0.04
#   Between 7 a.m. and 7:59 a.m.                                 0.01
#   Black, n.o.s.                                                1.00
#   Caucasian (White), n.o.s.                                    0.02
#   Chinese                                                     -0.07
#   Filipino                                                    -0.04
#   Government transfers (%)                                    -0.00
#   In the labour force                                          0.07
#   Indigenous identity                                          0.02
#   Major repairs needed                                         0.02
#   Median value of dwellings ($)                                0.07
#   Movers                                                       0.03
#   No certificate, diploma or degree                           -0.04
#   No high school diploma or equivalency certifi...            -0.04
#   Non-official languages                                      -0.06
#   Not in the labour force                                     -0.07
#   One-maintainer household                                     0.08
#   Postsecondary certificate, diploma or degree                 0.03
#   Public transit                                              -0.03
#   Renter                                                       0.07
#   South Asian, n.o.s.                                          0.03
#   Spending 30% or more of income on shelter costs              0.04
#   Total visible minority population                           -0.06
#   Under 5 years                                                0.03
# Average number of rooms per dwelling                          -0.10
# 2000 and before                                               -0.03
# 65 years and over                                             -0.05
#
# CHARACTERISTIC_NAME                                   Caucasian (White), n.o.s.  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                         0.01
#     Employed                                                               0.26
#     Unemployed                                                             0.08
#   5 to 14 years                                                            0.02
#   African American                                                         0.02
#   All occupations                                                          0.06
#   Average total income of household in 2020 ($)                            0.09
#   Between 7 a.m. and 7:59 a.m.                                             0.14
#   Black, n.o.s.                                                            0.02
#   Caucasian (White), n.o.s.                                                1.00
#   Chinese                                                                 -0.36
#   Filipino                                                                -0.18
#   Government transfers (%)                                                -0.15
#   In the labour force                                                      0.27
#   Indigenous identity                                                      0.06
#   Major repairs needed                                                     0.12
#   Median value of dwellings ($)                                            0.08
#   Movers                                                                   0.19
#   No certificate, diploma or degree                                       -0.25
#   No high school diploma or equivalency certifi...                        -0.24
#   Non-official languages                                                  -0.38
#   Not in the labour force                                                 -0.28
#   One-maintainer household                                                 0.23
#   Postsecondary certificate, diploma or degree                             0.31
#   Public transit                                                          -0.05
#   Renter                                                                   0.25
#   South Asian, n.o.s.                                                     -0.00
#   Spending 30% or more of income on shelter costs                          0.14
#   Total visible minority population                                       -0.41
#   Under 5 years                                                            0.06
# Average number of rooms per dwelling                                      -0.29
# 2000 and before                                                            0.10
# 65 years and over                                                         -0.19
#
# CHARACTERISTIC_NAME                                 ...  \
# CHARACTERISTIC_NAME                                 ...
#     Average total income in 2020 among recipien...  ...
#     Employed                                        ...
#     Unemployed                                      ...
#   5 to 14 years                                     ...
#   African American                                  ...
#   All occupations                                   ...
#   Average total income of household in 2020 ($)     ...
#   Between 7 a.m. and 7:59 a.m.                      ...
#   Black, n.o.s.                                     ...
#   Caucasian (White), n.o.s.                         ...
#   Chinese                                           ...
#   Filipino                                          ...
#   Government transfers (%)                          ...
#   In the labour force                               ...
#   Indigenous identity                               ...
#   Major repairs needed                              ...
#   Median value of dwellings ($)                     ...
#   Movers                                            ...
#   No certificate, diploma or degree                 ...
#   No high school diploma or equivalency certifi...  ...
#   Non-official languages                            ...
#   Not in the labour force                           ...
#   One-maintainer household                          ...
#   Postsecondary certificate, diploma or degree      ...
#   Public transit                                    ...
#   Renter                                            ...
#   South Asian, n.o.s.                               ...
#   Spending 30% or more of income on shelter costs   ...
#   Total visible minority population                 ...
#   Under 5 years                                     ...
# Average number of rooms per dwelling                ...
# 2000 and before                                     ...
# 65 years and over                                   ...
#
# CHARACTERISTIC_NAME                                   Postsecondary certificate, diploma or degree  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                                           -0.13
#     Employed                                                                                  0.47
#     Unemployed                                                                               -0.10
#   5 to 14 years                                                                               0.18
#   African American                                                                            0.03
#   All occupations                                                                             0.23
#   Average total income of household in 2020 ($)                                              -0.01
#   Between 7 a.m. and 7:59 a.m.                                                                0.16
#   Black, n.o.s.                                                                               0.03
#   Caucasian (White), n.o.s.                                                                   0.31
#   Chinese                                                                                    -0.50
#   Filipino                                                                                   -0.41
#   Government transfers (%)                                                                   -0.67
#   In the labour force                                                                         0.43
#   Indigenous identity                                                                        -0.10
#   Major repairs needed                                                                        0.04
#   Median value of dwellings ($)                                                               0.05
#   Movers                                                                                      0.47
#   No certificate, diploma or degree                                                          -0.88
#   No high school diploma or equivalency certifi...                                           -0.87
#   Non-official languages                                                                     -0.55
#   Not in the labour force                                                                    -0.46
#   One-maintainer household                                                                    0.29
#   Postsecondary certificate, diploma or degree                                                1.00
#   Public transit                                                                             -0.30
#   Renter                                                                                      0.17
#   South Asian, n.o.s.                                                                        -0.04
#   Spending 30% or more of income on shelter costs                                             0.34
#   Total visible minority population                                                          -0.63
#   Under 5 years                                                                               0.19
# Average number of rooms per dwelling                                                         -0.26
# 2000 and before                                                                               0.04
# 65 years and over                                                                            -0.29
#
# CHARACTERISTIC_NAME                                   Public transit  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...              0.29
#     Employed                                                    0.10
#     Unemployed                                                  0.22
#   5 to 14 years                                                -0.16
#   African American                                              0.04
#   All occupations                                               0.04
#   Average total income of household in 2020 ($)                 0.27
#   Between 7 a.m. and 7:59 a.m.                                 -0.00
#   Black, n.o.s.                                                -0.03
#   Caucasian (White), n.o.s.                                    -0.05
#   Chinese                                                      -0.04
#   Filipino                                                      0.48
#   Government transfers (%)                                      0.46
#   In the labour force                                           0.14
#   Indigenous identity                                           0.08
#   Major repairs needed                                          0.09
#   Median value of dwellings ($)                                 0.05
#   Movers                                                        0.05
#   No certificate, diploma or degree                             0.23
#   No high school diploma or equivalency certifi...              0.25
#   Non-official languages                                        0.27
#   Not in the labour force                                      -0.07
#   One-maintainer household                                      0.02
#   Postsecondary certificate, diploma or degree                 -0.30
#   Public transit                                                1.00
#   Renter                                                        0.30
#   South Asian, n.o.s.                                           0.05
#   Spending 30% or more of income on shelter costs               0.00
#   Total visible minority population                             0.27
#   Under 5 years                                                -0.13
# Average number of rooms per dwelling                           -0.24
# 2000 and before                                                 0.03
# 65 years and over                                              -0.11
#
# CHARACTERISTIC_NAME                                   Renter  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...      0.04
#     Employed                                            0.37
#     Unemployed                                          0.27
#   5 to 14 years                                        -0.15
#   African American                                      0.05
#   All occupations                                      -0.03
#   Average total income of household in 2020 ($)         0.18
#   Between 7 a.m. and 7:59 a.m.                          0.11
#   Black, n.o.s.                                         0.07
#   Caucasian (White), n.o.s.                             0.25
#   Chinese                                              -0.56
#   Filipino                                             -0.01
#   Government transfers (%)                              0.22
#   In the labour force                                   0.41
#   Indigenous identity                                   0.27
#   Major repairs needed                                  0.23
#   Median value of dwellings ($)                        -0.16
#   Movers                                                0.42
#   No certificate, diploma or degree                    -0.15
#   No high school diploma or equivalency certifi...     -0.11
#   Non-official languages                               -0.30
#   Not in the labour force                              -0.34
#   One-maintainer household                              0.62
#   Postsecondary certificate, diploma or degree          0.17
#   Public transit                                        0.30
#   Renter                                                1.00
#   South Asian, n.o.s.                                   0.03
#   Spending 30% or more of income on shelter costs       0.25
#   Total visible minority population                    -0.37
#   Under 5 years                                        -0.05
# Average number of rooms per dwelling                   -0.81
# 2000 and before                                         0.21
# 65 years and over                                      -0.36
#
# CHARACTERISTIC_NAME                                   South Asian, n.o.s.  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                   0.04
#     Employed                                                         0.02
#     Unemployed                                                       0.02
#   5 to 14 years                                                     -0.01
#   African American                                                   0.08
#   All occupations                                                    0.01
#   Average total income of household in 2020 ($)                      0.03
#   Between 7 a.m. and 7:59 a.m.                                      -0.01
#   Black, n.o.s.                                                      0.03
#   Caucasian (White), n.o.s.                                         -0.00
#   Chinese                                                           -0.03
#   Filipino                                                           0.03
#   Government transfers (%)                                           0.03
#   In the labour force                                                0.03
#   Indigenous identity                                               -0.03
#   Major repairs needed                                              -0.04
#   Median value of dwellings ($)                                      0.03
#   Movers                                                             0.02
#   No certificate, diploma or degree                                  0.02
#   No high school diploma or equivalency certifi...                   0.02
#   Non-official languages                                             0.09
#   Not in the labour force                                           -0.06
#   One-maintainer household                                          -0.05
#   Postsecondary certificate, diploma or degree                      -0.04
#   Public transit                                                     0.05
#   Renter                                                             0.03
#   South Asian, n.o.s.                                                1.00
#   Spending 30% or more of income on shelter costs                   -0.02
#   Total visible minority population                                  0.10
#   Under 5 years                                                     -0.00
# Average number of rooms per dwelling                                -0.02
# 2000 and before                                                     -0.09
# 65 years and over                                                   -0.06
#
# CHARACTERISTIC_NAME                                   Spending 30% or more of income on shelter costs  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                                               0.26
#     Employed                                                                                     0.08
#     Unemployed                                                                                   0.06
#   5 to 14 years                                                                                  0.12
#   African American                                                                               0.01
#   All occupations                                                                                0.05
#   Average total income of household in 2020 ($)                                                  0.31
#   Between 7 a.m. and 7:59 a.m.                                                                  -0.02
#   Black, n.o.s.                                                                                  0.04
#   Caucasian (White), n.o.s.                                                                      0.14
#   Chinese                                                                                       -0.07
#   Filipino                                                                                      -0.19
#   Government transfers (%)                                                                      -0.13
#   In the labour force                                                                            0.09
#   Indigenous identity                                                                           -0.13
#   Major repairs needed                                                                          -0.03
#   Median value of dwellings ($)                                                                 -0.06
#   Movers                                                                                         0.41
#   No certificate, diploma or degree                                                             -0.36
#   No high school diploma or equivalency certifi...                                              -0.36
#   Non-official languages                                                                         0.02
#   Not in the labour force                                                                       -0.12
#   One-maintainer household                                                                       0.31
#   Postsecondary certificate, diploma or degree                                                   0.34
#   Public transit                                                                                 0.00
#   Renter                                                                                         0.25
#   South Asian, n.o.s.                                                                           -0.02
#   Spending 30% or more of income on shelter costs                                                1.00
#   Total visible minority population                                                             -0.07
#   Under 5 years                                                                                  0.02
# Average number of rooms per dwelling                                                            -0.19
# 2000 and before                                                                                 -0.11
# 65 years and over                                                                               -0.19
#
# CHARACTERISTIC_NAME                                   Total visible minority population  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                                 0.20
#     Employed                                                                      -0.42
#     Unemployed                                                                    -0.01
#   5 to 14 years                                                                   -0.05
#   African American                                                                -0.08
#   All occupations                                                                 -0.15
#   Average total income of household in 2020 ($)                                    0.06
#   Between 7 a.m. and 7:59 a.m.                                                    -0.22
#   Black, n.o.s.                                                                   -0.06
#   Caucasian (White), n.o.s.                                                       -0.41
#   Chinese                                                                          0.76
#   Filipino                                                                         0.50
#   Government transfers (%)                                                         0.39
#   In the labour force                                                             -0.41
#   Indigenous identity                                                             -0.28
#   Major repairs needed                                                            -0.27
#   Median value of dwellings ($)                                                   -0.00
#   Movers                                                                          -0.28
#   No certificate, diploma or degree                                                0.54
#   No high school diploma or equivalency certifi...                                 0.51
#   Non-official languages                                                           0.94
#   Not in the labour force                                                          0.36
#   One-maintainer household                                                        -0.43
#   Postsecondary certificate, diploma or degree                                    -0.63
#   Public transit                                                                   0.27
#   Renter                                                                          -0.37
#   South Asian, n.o.s.                                                              0.10
#   Spending 30% or more of income on shelter costs                                 -0.07
#   Total visible minority population                                                1.00
#   Under 5 years                                                                   -0.20
# Average number of rooms per dwelling                                               0.40
# 2000 and before                                                                   -0.36
# 65 years and over                                                                  0.19
#
# CHARACTERISTIC_NAME                                   Under 5 years  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...             0.00
#     Employed                                                   0.06
#     Unemployed                                                -0.02
#   5 to 14 years                                                0.12
#   African American                                             0.03
#   All occupations                                              0.02
#   Average total income of household in 2020 ($)                0.01
#   Between 7 a.m. and 7:59 a.m.                                 0.05
#   Black, n.o.s.                                                0.03
#   Caucasian (White), n.o.s.                                    0.06
#   Chinese                                                     -0.07
#   Filipino                                                    -0.18
#   Government transfers (%)                                    -0.18
#   In the labour force                                          0.04
#   Indigenous identity                                          0.02
#   Major repairs needed                                         0.06
#   Median value of dwellings ($)                                0.04
#   Movers                                                       0.05
#   No certificate, diploma or degree                           -0.17
#   No high school diploma or equivalency certifi...            -0.18
#   Non-official languages                                      -0.24
#   Not in the labour force                                     -0.06
#   One-maintainer household                                     0.01
#   Postsecondary certificate, diploma or degree                 0.19
#   Public transit                                              -0.13
#   Renter                                                      -0.05
#   South Asian, n.o.s.                                         -0.00
#   Spending 30% or more of income on shelter costs              0.02
#   Total visible minority population                           -0.20
#   Under 5 years                                                1.00
# Average number of rooms per dwelling                           0.06
# 2000 and before                                                0.02
# 65 years and over                                             -0.10
#
# CHARACTERISTIC_NAME                                 Average number of rooms per dwelling  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...                                 -0.05
#     Employed                                                                       -0.45
#     Unemployed                                                                     -0.23
#   5 to 14 years                                                                     0.13
#   African American                                                                 -0.06
#   All occupations                                                                   0.00
#   Average total income of household in 2020 ($)                                    -0.23
#   Between 7 a.m. and 7:59 a.m.                                                     -0.18
#   Black, n.o.s.                                                                    -0.10
#   Caucasian (White), n.o.s.                                                        -0.29
#   Chinese                                                                           0.59
#   Filipino                                                                          0.02
#   Government transfers (%)                                                         -0.14
#   In the labour force                                                              -0.49
#   Indigenous identity                                                              -0.24
#   Major repairs needed                                                             -0.22
#   Median value of dwellings ($)                                                    -0.16
#   Movers                                                                           -0.45
#   No certificate, diploma or degree                                                 0.22
#   No high school diploma or equivalency certifi...                                  0.18
#   Non-official languages                                                            0.32
#   Not in the labour force                                                           0.43
#   One-maintainer household                                                         -0.68
#   Postsecondary certificate, diploma or degree                                     -0.26
#   Public transit                                                                   -0.24
#   Renter                                                                           -0.81
#   South Asian, n.o.s.                                                              -0.02
#   Spending 30% or more of income on shelter costs                                  -0.19
#   Total visible minority population                                                 0.40
#   Under 5 years                                                                     0.06
# Average number of rooms per dwelling                                                1.00
# 2000 and before                                                                    -0.07
# 65 years and over                                                                   0.38
#
# CHARACTERISTIC_NAME                                 2000 and before  \
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...             0.00
#     Employed                                                   0.02
#     Unemployed                                                 0.07
#   5 to 14 years                                               -0.12
#   African American                                             0.04
#   All occupations                                             -0.01
#   Average total income of household in 2020 ($)                0.02
#   Between 7 a.m. and 7:59 a.m.                                 0.07
#   Black, n.o.s.                                               -0.03
#   Caucasian (White), n.o.s.                                    0.10
#   Chinese                                                     -0.29
#   Filipino                                                    -0.08
#   Government transfers (%)                                     0.12
#   In the labour force                                          0.03
#   Indigenous identity                                          0.12
#   Major repairs needed                                         0.33
#   Median value of dwellings ($)                               -0.10
#   Movers                                                      -0.19
#   No certificate, diploma or degree                           -0.04
#   No high school diploma or equivalency certifi...            -0.02
#   Non-official languages                                      -0.34
#   Not in the labour force                                      0.03
#   One-maintainer household                                     0.14
#   Postsecondary certificate, diploma or degree                 0.04
#   Public transit                                               0.03
#   Renter                                                       0.21
#   South Asian, n.o.s.                                         -0.09
#   Spending 30% or more of income on shelter costs             -0.11
#   Total visible minority population                           -0.36
#   Under 5 years                                                0.02
# Average number of rooms per dwelling                          -0.07
# 2000 and before                                                1.00
# 65 years and over                                              0.18
#
# CHARACTERISTIC_NAME                                 65 years and over
# CHARACTERISTIC_NAME
#     Average total income in 2020 among recipien...              -0.06
#     Employed                                                    -0.66
#     Unemployed                                                  -0.17
#   5 to 14 years                                                 -0.11
#   African American                                              -0.02
#   All occupations                                               -0.22
#   Average total income of household in 2020 ($)                 -0.12
#   Between 7 a.m. and 7:59 a.m.                                  -0.07
#   Black, n.o.s.                                                 -0.05
#   Caucasian (White), n.o.s.                                     -0.19
#   Chinese                                                        0.35
#   Filipino                                                      -0.02
#   Government transfers (%)                                       0.19
#   In the labour force                                           -0.68
#   Indigenous identity                                           -0.10
#   Major repairs needed                                          -0.06
#   Median value of dwellings ($)                                 -0.11
#   Movers                                                        -0.47
#   No certificate, diploma or degree                              0.29
#   No high school diploma or equivalency certifi...               0.29
#   Non-official languages                                         0.22
#   Not in the labour force                                        0.63
#   One-maintainer household                                      -0.11
#   Postsecondary certificate, diploma or degree                  -0.29
#   Public transit                                                -0.11
#   Renter                                                        -0.36
#   South Asian, n.o.s.                                           -0.06
#   Spending 30% or more of income on shelter costs               -0.19
#   Total visible minority population                              0.19
#   Under 5 years                                                 -0.10
# Average number of rooms per dwelling                             0.38
# 2000 and before                                                  0.18
# 65 years and over                                                1.00
#
# [33 rows x 33 columns]

# %% [markdown]
# Plotting the Correlation matrix as Heatmap

# %%
fig = plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', annot_kws={"fontsize": 6}, cmap='YlGnBu', vmin=-1, vmax=1)
# Out:
# <Axes: xlabel='CHARACTERISTIC_NAME', ylabel='CHARACTERISTIC_NAME'>

# %% [markdown]
# # Selecting the correlation value higher than 0.9

# %%
def find_high_correlation(corr_matrix, threshold, variable_names):
    features = []
    Nvar = corr_matrix.shape[0]
    
    for i in range(Nvar):
        for j in range(i + 1, Nvar):
            if abs(corr_matrix[i, j]) > threshold:
                var1 = variable_names[i]
                var2 = variable_names[j]
                features.append((var1, var2, corr_matrix[i, j]))
    
    return features


variable_names = pivot_df_filled.columns.tolist()

corr_features = find_high_correlation(corr_matrix.values, 0.9, variable_names)
corr_features
# Out:
# [('    Average total income in 2020 among recipients ($)',
#   '  Average total income of household in 2020 ($)',
#   0.98),
#  ('    Employed', '  In the labour force', 0.96),
#  ('  No certificate, diploma or degree',
#   '  No high school diploma or equivalency certificate',
#   0.99),
#  ('  Non-official languages', '  Total visible minority population', 0.94)]

# %% [markdown]
# # Dropping some variables after correlation matrix

# %%
import pandas as pd

variables_to_drop = ['  Average total income in 2020 among recipients ($)', '  In the labour force',
                     '  No high school diploma or equivalency certificate', '  Non-official languages']

# Removing spaces and convert to lowercase
variables_to_drop = [column.strip().lower() for column in variables_to_drop]
pivot_df_filled.columns = pivot_df_filled.columns.str.strip().str.lower()
pivot_df_filled_dropped = pivot_df_filled.drop(variables_to_drop, axis=1)
#pivot_df_filled_dropped = pivot_df_filled_dropped.reset_index(drop=True)


pivot_df_filled_dropped.round(2)
# Out:
# CHARACTERISTIC_NAME  employed  unemployed  5 to 14 years  african american  \
# GEO_NAME
# 59150307                61.82        6.78           23.7               0.0
# 59150308                68.09        4.26           21.9               0.0
# 59150309                70.00        3.64            9.5               0.0
# 59150310                74.63        8.40           17.9               0.0
# 59150311                52.63       10.84           19.4               0.0
# ...                       ...         ...            ...               ...
# 59154192                63.44        4.44           19.0               0.0
# 59154193                73.81        4.68           18.2               0.0
# 59154194                45.16        7.14           15.9               0.0
# 59154195                43.08        7.87           13.4               0.0
# 59154196                55.56        7.53            8.9               0.0
#
# CHARACTERISTIC_NAME  all occupations  \
# GEO_NAME
# 59150307                        96.3
# 59150308                       100.0
# 59150309                        96.1
# 59150310                        99.1
# 59150311                        96.2
# ...                              ...
# 59154192                       100.0
# 59154193                        99.2
# 59154194                        98.6
# 59154195                        97.3
# 59154196                        96.0
#
# CHARACTERISTIC_NAME  average total income of household in 2020 ($)  \
# GEO_NAME
# 59150307                                                     89.47
# 59150308                                                     89.67
# 59150309                                                     91.29
# 59150310                                                     94.45
# 59150311                                                     91.29
# ...                                                            ...
# 59154192                                                     86.65
# 59154193                                                     90.86
# 59154194                                                     91.18
# 59154195                                                     91.99
# 59154196                                                     90.98
#
# CHARACTERISTIC_NAME  between 7 a.m. and 7:59 a.m.  black, n.o.s.  \
# GEO_NAME
# 59150307                                     23.1            0.0
# 59150308                                     17.1            0.0
# 59150309                                     18.2            0.0
# 59150310                                     23.6            0.0
# 59150311                                     20.0            0.0
# ...                                           ...            ...
# 59154192                                     20.6            0.0
# 59154193                                     23.2            0.0
# 59154194                                     21.2            0.0
# 59154195                                     30.4            0.0
# 59154196                                     29.7            0.0
#
# CHARACTERISTIC_NAME  caucasian (white), n.o.s.  chinese  ...  \
# GEO_NAME                                                 ...
# 59150307                                   0.0     12.7  ...
# 59150308                                   0.0     21.8  ...
# 59150309                                   1.6     21.9  ...
# 59150310                                   2.0     15.3  ...
# 59150311                                   0.0     40.4  ...
# ...                                        ...      ...  ...
# 59154192                                   3.8      9.0  ...
# 59154193                                   0.0      9.2  ...
# 59154194                                   0.0     22.4  ...
# 59154195                                   0.0     50.3  ...
# 59154196                                   0.0     45.7  ...
#
# CHARACTERISTIC_NAME  postsecondary certificate, diploma or degree  \
# GEO_NAME
# 59150307                                                     60.2
# 59150308                                                     64.9
# 59150309                                                     58.7
# 59150310                                                     62.6
# 59150311                                                     49.4
# ...                                                           ...
# 59154192                                                     87.2
# 59154193                                                     82.5
# 59154194                                                     49.1
# 59154195                                                     53.2
# 59154196                                                     44.5
#
# CHARACTERISTIC_NAME  public transit  renter  south asian, n.o.s.  \
# GEO_NAME
# 59150307                       11.5    27.8                  0.0
# 59150308                       14.6    29.5                  0.0
# 59150309                       29.5    38.5                  0.0
# 59150310                       38.9    78.5                  0.0
# 59150311                       17.1    44.4                  0.0
# ...                             ...     ...                  ...
# 59154192                        6.3     9.9                  0.0
# 59154193                       14.5    56.9                  0.0
# 59154194                       26.9    56.5                  3.7
# 59154195                       15.2    39.6                  0.0
# 59154196                       32.4    38.9                  0.0
#
# CHARACTERISTIC_NAME  spending 30% or more of income on shelter costs  \
# GEO_NAME
# 59150307                                                        22.6
# 59150308                                                        26.7
# 59150309                                                        23.1
# 59150310                                                        44.3
# 59150311                                                        30.6
# ...                                                              ...
# 59154192                                                        24.0
# 59154193                                                        23.5
# 59154194                                                        26.1
# 59154195                                                        20.8
# 59154196                                                        27.3
#
# CHARACTERISTIC_NAME  total visible minority population  under 5 years  \
# GEO_NAME
# 59150307                                          33.1           10.5
# 59150308                                          33.6           21.9
# 59150309                                          45.3            4.8
# 59150310                                          40.9            7.7
# 59150311                                          64.9            0.0
# ...                                                ...            ...
# 59154192                                          23.2            9.5
# 59154193                                          24.9           10.9
# 59154194                                          64.2            7.2
# 59154195                                          91.2            2.4
# 59154196                                          90.2            5.9
#
# CHARACTERISTIC_NAME  average number of rooms per dwelling  2000 and before  \
# GEO_NAME
# 59150307                                              7.2             77.8
# 59150308                                              6.5             86.3
# 59150309                                              5.4             59.7
# 59150310                                              3.3             58.3
# 59150311                                              6.0             75.0
# ...                                                   ...              ...
# 59154192                                              4.7             91.2
# 59154193                                              3.7             97.1
# 59154194                                              5.2             71.6
# 59154195                                              5.8             72.9
# 59154196                                              6.6             68.6
#
# CHARACTERISTIC_NAME  65 years and over
# GEO_NAME
# 59150307                          27.8
# 59150308                          31.8
# 59150309                          17.3
# 59150310                           6.3
# 59150311                          30.5
# ...                                ...
# 59154192                          21.8
# 59154193                          15.7
# 59154194                          21.7
# 59154195                          29.3
# 59154196                          31.5
#
# [1023 rows x 29 columns]

# %%
pivot_df_filled_dropped.to_csv('Selected_variables.csv')
df1 = pd.read_csv('Selected_variables.csv')
